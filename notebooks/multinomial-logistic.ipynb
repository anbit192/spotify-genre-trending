# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder

# %%
df = pd.read_csv("../data/train_data_with_genre.csv")
df.head()
# Out:
#                  track_id        track_name               artist_id
# 0  2plbrEY59IikOBgBGLjaoe  Die With A Smile  1HY2Jd0NmPuamShAr6KMms  \
# 1  5R8dQOPq8haW94K7mgERlO        Poker Face  1HY2Jd0NmPuamShAr6KMms
# 2  0SiywuOBRcynK0uKGWdCnn       Bad Romance  1HY2Jd0NmPuamShAr6KMms
# 3  2x7MyWybabEz6Y6wvHuwGE        Just Dance  1HY2Jd0NmPuamShAr6KMms
# 4  11BKm0j4eYoCPPpCONAVwA       Bloody Mary  1HY2Jd0NmPuamShAr6KMms
#
#   artist_name  popularity                         album_name genre
# 0   Lady Gaga         100                   Die With A Smile   pop  \
# 1   Lady Gaga          76                           The Fame   pop
# 2   Lady Gaga          82  The Fame Monster (Deluxe Edition)   pop
# 3   Lady Gaga          74                           The Fame   pop
# 4   Lady Gaga          73    Born This Way (Special Edition)   pop
#
#            artist_genres  duration_ms  explicit  ...  loudness  mode
# 0  art pop,dance pop,pop       251667     False  ...    -7.777     0  \
# 1  art pop,dance pop,pop       237200     False  ...    -4.618     1
# 2  art pop,dance pop,pop       294573      True  ...    -3.752     1
# 3  art pop,dance pop,pop       241933     False  ...    -4.541     0
# 4  art pop,dance pop,pop       244760     False  ...    -6.365     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0       0.0304       0.30800          0.000000    0.1220    0.535  157.969  \
# 1       0.0787       0.11900          0.000002    0.1210    0.774  119.001
# 2       0.0363       0.00314          0.000053    0.0842    0.714  119.007
# 3       0.0311       0.02640          0.000043    0.1810    0.745  118.990
# 4       0.0291       0.01070          0.000002    0.1130    0.440   99.998
#
#                                         analysis_url  time_signature
# 0  https://api.spotify.com/v1/audio-analysis/2plb...               3
# 1  https://api.spotify.com/v1/audio-analysis/5R8d...               4
# 2  https://api.spotify.com/v1/audio-analysis/0Siy...               4
# 3  https://api.spotify.com/v1/audio-analysis/2x7M...               4
# 4  https://api.spotify.com/v1/audio-analysis/11BK...               4
#
# [5 rows x 23 columns]

# %%
df = df.sample(frac=1)

# %%
def bpm_to_tempo(bpm):
    if bpm <= 20:
        return 0  # Larghissimo
    elif 21 <= bpm <= 40:
        return 1  # Grave
    elif 41 <= bpm <= 50:
        return 2  # Lento
    elif 51 <= bpm <= 60:
        return 3  # Largo
    elif 61 <= bpm <= 66:
        return 4  # Larghetto
    elif 67 <= bpm <= 75:
        return 5  # Adagio
    elif 76 <= bpm <= 80:
        return 6  # Adagietto
    elif 81 <= bpm <= 100:
        return 7  # Andante
    elif 101 <= bpm <= 120:
        return 8  # Moderato
    elif 121 <= bpm <= 160:
        return 9  # Allegro
    elif 161 <= bpm <= 175:
        return 10  # Vivace
    elif 176 <= bpm <= 200:
        return 11  # Presto
    else:
        return 12  # Prestissimo

classical_tempo = [bpm_to_tempo(bpm) for bpm in df["tempo"]]
df["tempo"] = classical_tempo

# %% [markdown]
# # Multinomial Logistic work with both continuous and categorical data, so...

# %%
X = df.drop(columns=['track_id', 'track_name', 'artist_id', 'artist_name', 'popularity', 'key', 'mode',
       'album_name', 'genre', 'artist_genres', 'analysis_url', 'duration_ms'])
X.head()
# Out:
#       explicit  danceability  energy  loudness  speechiness  acousticness
# 5915     False         0.639   0.791    -4.443       0.2540        0.0275  \
# 5387      True         0.824   0.878    -5.020       0.2730        0.1690
# 3313     False         0.507   0.309   -14.429       0.0383        0.7840
# 4653     False         0.563   0.741   -11.947       0.0486        0.6020
# 197       True         0.795   0.594    -6.200       0.0748        0.1120
#
#       instrumentalness  liveness  valence  tempo  time_signature
# 5915           0.00000     0.362    0.933      0               4
# 5387           0.00000     0.369    0.645      0               4
# 3313           0.00000     0.138    0.716      0               4
# 4653           0.00251     0.325    0.967      0               4
# 197            0.00000     0.162    0.409      0               4

# %%
# keys = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]

# %%
X_encoded = pd.get_dummies(X, columns=["time_signature"])

# %%
X_encoded
# Out:
#       explicit  danceability  energy  loudness  speechiness  acousticness
# 5915     False         0.639   0.791    -4.443       0.2540       0.02750  \
# 5387      True         0.824   0.878    -5.020       0.2730       0.16900
# 3313     False         0.507   0.309   -14.429       0.0383       0.78400
# 4653     False         0.563   0.741   -11.947       0.0486       0.60200
# 197       True         0.795   0.594    -6.200       0.0748       0.11200
# ...        ...           ...     ...       ...          ...           ...
# 6822     False         0.297   0.634    -7.927       0.0335       0.00141
# 1783     False         0.622   0.931    -4.660       0.0507       0.10600
# 4828     False         0.659   0.779    -5.580       0.0608       0.26400
# 4036     False         0.331   0.178   -22.341       0.0384       0.99500
# 6800     False         0.536   0.865    -6.988       0.1290       0.00109
#
#       instrumentalness  liveness  valence  tempo  time_signature_0
# 5915          0.000000    0.3620   0.9330      0             False  \
# 5387          0.000000    0.3690   0.6450      0             False
# 3313          0.000000    0.1380   0.7160      0             False
# 4653          0.002510    0.3250   0.9670      0             False
# 197           0.000000    0.1620   0.4090      0             False
# ...                ...       ...      ...    ...               ...
# 6822          0.175000    0.2470   0.3310      0             False
# 1783          0.000002    0.3280   0.5210      0             False
# 4828          0.079200    0.0773   0.6300      0             False
# 4036          0.899000    0.1070   0.0937      0             False
# 6800          0.000239    0.1190   0.1630      0             False
#
#       time_signature_1  time_signature_3  time_signature_4  time_signature_5
# 5915             False             False              True             False
# 5387             False             False              True             False
# 3313             False             False              True             False
# 4653             False             False              True             False
# 197              False             False              True             False
# ...                ...               ...               ...               ...
# 6822             False             False              True             False
# 1783             False             False              True             False
# 4828             False             False              True             False
# 4036             False             False              True             False
# 6800             False             False              True             False
#
# [8187 rows x 15 columns]

# %%
y = df["genre"]

# %% [markdown]
# # split train test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y)

# %% [markdown]
# # Logistic model

# %%
lr = LogisticRegression(multi_class="multinomial", max_iter=10000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000, multi_class='multinomial')

# %%
y_preds = lr.predict(X_test)
y_preds
# Out:
# array(['acoustic', 'acoustic', 'rock', ..., 'reggae', 'pop', 'acoustic'],
#       dtype=object)

# %%
metrics.accuracy_score(y_test, y_preds)
# Out:
# 0.48851978505129456

# %% [markdown]
# # => Accuracy Multinomial logistic: 0.488
